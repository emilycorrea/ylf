# %% [markdown]
# <a href="https://colab.research.google.com/github/emilycorrea/ylf/blob/main/Emily_Correa_CS_361_Group_Reply_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Python is not difficult at all! I can do it!")

import matplotlib.pyplot as plt

plt.plot([0,6],[3,1])
# Out:
# Python is not difficult at all! I can do it!
